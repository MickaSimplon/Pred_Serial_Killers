# %% [markdown]
# ### Import librairy

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Import dataset

# %%
murder = r"E:\prog_perso\murder\SHR76_17.csv"
df = pd.read_csv(murder, sep=",")
df.head()
# Out:
#                  ID       CNTYFIPS      Ori    State          Agency  \
# 0  197601001AKASP00     Juneau, AK  AKASP00   Alaska  State Troopers
# 1  197601001AL00102  Jefferson, AL  AL00102  Alabama      Birmingham
# 2  197601001AL00104  Jefferson, AL  AL00104  Alabama       Fairfield
# 3  197601001AL00106  Jefferson, AL  AL00106  Alabama           Leeds
# 4  197601001AL00201     Mobile, AL  AL00201  Alabama          Mobile
#
#            Agentype Source Solved  Year    Month  ...  \
# 0  Primary state LE    FBI    Yes  1976  January  ...
# 1  Municipal police    FBI    Yes  1976  January  ...
# 2  Municipal police    FBI    Yes  1976  January  ...
# 3  Municipal police    FBI    Yes  1976  January  ...
# 4  Municipal police    FBI    Yes  1976  January  ...
#
#                  OffEthnic                       Weapon  Relationship  \
# 0  Unknown or not reported  Knife or cutting instrument       Husband
# 1  Unknown or not reported                      Shotgun  Acquaintance
# ...

# %%
df.columns
# Out:
# Index(['ID', 'CNTYFIPS', 'Ori', 'State', 'Agency', 'Agentype', 'Source',
#        'Solved', 'Year', 'Month', 'Incident', 'ActionType', 'Homicide',
#        'Situation', 'VicAge', 'VicSex', 'VicRace', 'VicEthnic', 'OffAge',
#        'OffSex', 'OffRace', 'OffEthnic', 'Weapon', 'Relationship',
#        'Circumstance', 'Subcircum', 'VicCount', 'OffCount', 'FileDate',
#        'fstate', 'MSA'],
#       dtype='object')

# %% [markdown]
# ### Analyse DataSet

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 771025 entries, 0 to 771024
# Data columns (total 31 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   ID            771025 non-null  object
#  1   CNTYFIPS      771025 non-null  object
#  2   Ori           771025 non-null  object
#  3   State         771025 non-null  object
#  4   Agency        771025 non-null  object
#  5   Agentype      771025 non-null  object
#  6   Source        771025 non-null  object
#  7   Solved        771025 non-null  object
#  8   Year          771025 non-null  int64
#  9   Month         771025 non-null  object
#  10  Incident      771025 non-null  int64
#  11  ActionType    771025 non-null  object
#  12  Homicide      771025 non-null  object
#  13  Situation     771025 non-null  object
#  14  VicAge        771025 non-null  int64
#  15  VicSex        771025 non-null  object
#  16  VicRace       771025 non-null  object
# ...

# %%
df.nunique()
# Out:
# ID              736646
# CNTYFIPS          3061
# Ori              12744
# State               51
# Agency            9455
# Agentype             7
# Source               2
# Solved               2
# Year                42
# Month               12
# Incident          1000
# ActionType           2
# Homicide             2
# Situation            6
# VicAge             101
# VicSex               3
# VicRace              6
# VicEthnic            3
# OffAge             101
# OffSex               3
# OffRace              6
# OffEthnic            3
# Weapon              18
# Relationship        29
# Circumstance        32
# Subcircum            7
# VicCount            11
# OffCount            11
# FileDate          5448
# fstate              51
# MSA                409
# dtype: int64

# %%
num_missing_X = lambda x: sum(x.isnull())
print("Valeurs manquantes par colonne:\n", df.apply(num_missing_X, axis=0))
# Out:
# Valeurs manquantes par colonne:
#  ID                   0
# CNTYFIPS             0
# Ori                  0
# State                0
# Agency               0
# Agentype             0
# Source               0
# Solved               0
# Year                 0
# Month                0
# Incident             0
# ActionType           0
# Homicide             0
# Situation            0
# VicAge               0
# VicSex               0
# VicRace              0
# VicEthnic            0
# OffAge               0
# OffSex               0
# OffRace              0
# OffEthnic            0
# Weapon               0
# Relationship         0
# Circumstance         0
# Subcircum       741769
# VicCount             0
# OffCount             0
# FileDate          1232
# fstate               0
# MSA                  0
# dtype: int64

# %%
df.describe()
# Out:
#                 Year       Incident         VicAge         OffAge  \
# count  771025.000000  771025.000000  771025.000000  771025.000000
# mean     1995.394204      28.253578      47.929768     352.600519
# std        11.993360     108.087786     120.692392     456.083865
# min      1976.000000       0.000000       0.000000       0.000000
# 25%      1985.000000       1.000000      22.000000      24.000000
# 50%      1994.000000       2.000000      30.000000      37.000000
# 75%      2006.000000      10.000000      42.000000     999.000000
# max      2017.000000     999.000000     999.000000     999.000000
#
#             VicCount       OffCount       FileDate
# count  771025.000000  771025.000000  769793.000000
# mean        0.125397       0.181270   51045.511017
# std         0.551271       0.583681   32616.739923
# min         0.000000       0.000000   10181.000000
# 25%         0.000000       0.000000   30108.000000
# 50%         0.000000       0.000000   32984.000000
# ...

# %%
df.hist(figsize= (20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021F2EF42908>,
# ...
#       dtype=object)

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20, 'figure.figsize': (10, 8)})
df.plot(kind="box");

# %% [markdown]
# ### Compte du nombre de 999 dans VicAge

# %%
df['VicAge'] = df['VicAge'].astype(int)
# methode 1
count = 0
for i in df['VicAge']:
    if i == 999:
        count += 1
print(count)
# Out:
# 12008

# %%
# Méthode 2
count2 = len(df[df['VicAge'] == 999])
print(count2)
# Out:
# 12008

# %%
import numpy as np
test = df.pivot_table(index= "State", values=["Solved", "VicRace"], aggfunc=np.sum )
print(test)
# Out:
#                                                                  Solved  \
# State
# Alabama               YesYesYesYesYesYesYesYesYesYesYesYesYesYesYesY...
# Alaska                YesYesYesYesYesYesYesYesYesYesNoYesYesYesYesYe...
# Arizona               YesNoYesYesYesYesYesYesNoYesYesYesYesNoNoYesYe...
# Arkansas              YesYesYesYesYesYesYesYesYesNoYesYesYesYesYesYe...
# California            YesYesYesYesNoYesYesYesYesYesNoYesYesNoYesYesY...
# Colorado              YesYesYesYesYesYesYesYesNoYesYesNoNoYesYesYesY...
# Connecticut           YesYesNoYesNoYesYesYesYesYesYesYesYesYesYesYes...
# Delaware              YesNoYesYesYesYesYesYesYesYesYesYesNoYesYesYes...
# District of Columbia  YesYesYesYesYesYesYesYesYesYesYesYesNoNoYesYes...
# Florida               YesYesYesYesNoYesYesYesYesNoYesYesYesYesYesYes...
# Georgia               YesYesYesYesYesYesYesYesYesYesNoYesYesYesYesNo...
# Hawaii                YesYesYesYesNoYesYesYesYesYesYesNoNoNoYesYesNo...
# ...

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from wordcloud import WordCloud, STOPWORDS
import nltk.tokenize as word_tokenize
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string
import re
from nltk.stem.porter import *
from nltk.tokenize import sent_tokenize
from sklearn.feature_extraction import stop_words

# %%
stopwords = set(STOPWORDS)
newStopWords = ['Relationship', 'VicRace', 'Homicide','State','Circumstance', 'Month']
stopwords.update(newStopWords)

wordcloud = WordCloud(
                          background_color='white',
                          stopwords=stopwords,
                          max_words=1500,
                          max_font_size=200, 
                          width=1000, height=600,
                          random_state=42,
                         ).generate(" ".join(df['Weapon'].astype(str)))

fig = plt.figure(figsize = (12,12))
plt.imshow(wordcloud)
plt.title("WORD CLOUD - Weapon", fontsize=25)
plt.axis('off')
plt.show()

# %%
stopwords = set(STOPWORDS)
newStopWords = ['Weapon', 'Relationship', 'VicRace','State','Homicide']
stopwords.update(newStopWords)

wordcloud = WordCloud(
                          background_color='white',
                          stopwords=stopwords,
                          max_words=1500,
                          max_font_size=200, 
                          width=1000, height=600,
                          random_state=42,
                         ).generate(" ".join(df['Circumstance'].astype(str)))

fig = plt.figure(figsize = (12,12))
plt.imshow(wordcloud)
plt.title("WORD CLOUD - Circumstance", fontsize=25)
plt.axis('off')
plt.show()

# %%
stopwords = set(STOPWORDS)
newStopWords = ['Weapon', 'VicRace', 'Homicide','State','Circumstance', 'Relationship']
stopwords.update(newStopWords)

wordcloud = WordCloud(
                          background_color='white',
                          stopwords=stopwords,
                          max_words=1500,
                          max_font_size=200, 
                          width=1000, height=600,
                          random_state=42,
                         ).generate(" ".join(df['Month'].astype(str)))

fig = plt.figure(figsize = (12,12))
plt.imshow(wordcloud)
plt.title("WORD CLOUD - Month", fontsize=25)
plt.axis('off')
plt.show()

# %%
stopwords = set(STOPWORDS)
newStopWords = ['Month', 'VicRace', 'Homicide','State','Circumstance', 'Weapon']
stopwords.update(newStopWords)

wordcloud = WordCloud(
                          background_color='white',
                          stopwords=stopwords,
                          max_words=1500,
                          max_font_size=200, 
                          width=1000, height=600,
                          random_state=42,
                         ).generate(" ".join(df['Relationship'].astype(str)))

fig = plt.figure(figsize = (12,12))
plt.imshow(wordcloud)
plt.title("WORD CLOUD - Relationship", fontsize=25)
plt.axis('off')
plt.show()

# %%
stopwords = set(STOPWORDS)
newStopWords = ['Month', 'Relationship', 'Homicide','State','Circumstance', 'Weapon']
stopwords.update(newStopWords)

wordcloud = WordCloud(
                          background_color='white',
                          stopwords=stopwords,
                          max_words=1500,
                          max_font_size=200, 
                          width=1000, height=600,
                          random_state=42,
                         ).generate(" ".join(df['VicRace'].astype(str)))

fig = plt.figure(figsize = (12,12))
plt.imshow(wordcloud)
plt.title("WORD CLOUD - Victime race", fontsize=25)
plt.axis('off')
plt.show()
